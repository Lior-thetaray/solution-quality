# %% [markdown]
# ### Init Context

# %%
from thetaray.api.context import init_context
import datetime
import yaml

import logging
logging.basicConfig(level=logging.DEBUG, format='%(message)s')

with open('/thetaray/git/solutions/domains/demo_ret_smb/config/spark_config.yaml') as spark_config_file:
    spark_config = yaml.load(spark_config_file, yaml.FullLoader)['spark_config_a']
context = init_context(execution_date=datetime.datetime(1970, 1, 1),
                       spark_conf=spark_config,
                       spark_master='local[*]')
# Out:
# 2025-05-29 10:18:49,006:INFO:thetaray.common.logging:start loading solution.....[ load_risks=True , solution_path=/thetaray/git/solutions/domains , settings_path=/thetaray/git/solutions/settings ]
# 2025-05-29 10:18:49,009:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-05-29 10:18:49,020:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_indiv_customer_insights, but data encryption is disabled in deployment
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,049:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,050:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:18:49,100:INFO:thetaray.common.logging:load_risks took: 0.0483551025390625
# 2025-05-29 10:18:49,102:INFO:thetaray.common.logging:Skip _connectors validation due to no connectors provided.
# 2025-05-29 10:18:49,113:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-05-29 10:18:49,113:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_indiv_customer_insights, but data encryption is disabled in deployment
# 2025-05-29 10:18:49,462:INFO:thetaray.common.logging:=== Started updating schema ===
# 2025-05-29 10:18:49,513:INFO:thetaray.common.logging:=== Started updating schema on Postgres ===
# 2025-05-29 10:18:51,581:INFO:thetaray.common.logging:found 43 tables in solution public schema
# 2025-05-29 10:18:51,584:INFO:thetaray.common.logging:demo_ret_smb_ef
# 2025-05-29 10:18:51,592:INFO:thetaray.common.logging:found 43 tables in solution public schema
# 2025-05-29 10:18:51,593:INFO:thetaray.common.logging:demo_ret_indiv_ef
# 2025-05-29 10:18:51,597:INFO:thetaray.common.logging:=== Finished updating schema ===
# 2025-05-29 10:18:52,166:INFO:thetaray.common.logging:=== Started updating schema for Datasets on Minio ===
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/29 10:18:54 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Hive Session ID = caf06653-9087-49ac-9720-ccd84c68e314
# 25/05/29 10:18:56 INFO SessionState: Hive Session ID = caf06653-9087-49ac-9720-ccd84c68e314
# 2025-05-29 10:18:59,648:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_smb_customers
# 25/05/29 10:18:59 INFO SQLStdHiveAccessController: Created SQLStdHiveAccessController for session context : HiveAuthzSessionContext [sessionString=caf06653-9087-49ac-9720-ccd84c68e314, clientType=HIVECLI]
# 2025-05-29 10:19:00,413:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_smb_customer_insights
# 2025-05-29 10:19:00,628:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_smb_customer_monthly
# 2025-05-29 10:19:00,826:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_smb_transactions
# 2025-05-29 10:19:01,029:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_indiv_customers
# 2025-05-29 10:19:01,232:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_indiv_customer_insights
# 2025-05-29 10:19:01,440:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_indiv_customer_monthly
# 2025-05-29 10:19:01,623:INFO:thetaray.common.logging:Creating metastore schema for dataset: demo_ret_indiv_transactions
# 2025-05-29 10:19:01,827:INFO:thetaray.common.logging:=== Finished updating schema for Datasets on Minio ===
# 2025-05-29 10:19:01,827:INFO:thetaray.common.logging:=== Started updating schema for Evaluation Flows on Minio ===
# 2025-05-29 10:19:03,337:INFO:thetaray.common.logging:Creating metastore schema for evaluation flow: demo_ret_smb_ef
# 2025-05-29 10:19:04,413:INFO:thetaray.common.logging:Creating metastore schema for evaluation flow: demo_ret_indiv_ef
# 2025-05-29 10:19:04,619:INFO:thetaray.common.logging:=== Finished updating schema for Evaluation Flows on Minio ===

# %% [markdown]
# ### Imports

# %%
from domains.demo_ret_smb.datasets.customer_monthly import customer_monthly_dataset
from domains.demo_ret_smb.datasets.customers import customers_dataset
from domains.demo_ret_smb.datasets.customer_insights import customer_insights_dataset
from domains.demo_ret_smb.datasets.transactions import transactions_dataset
from domains.demo_ret_smb.evaluation_flows.ef import evaluation_flow as ef
from domains.demo_ret_smb.graphs.graph import graph

from thetaray.api.evaluation import unblock_evaluation_for_execution_date
from thetaray.common.data_environment import DataEnvironment

from sqlalchemy import text
import os
from sqlalchemy import create_engine
import pandas as pd

# %% [markdown]
# ### Minio

# %%
context.drop_spark_execution_partition(customer_monthly_dataset().identifier, context.execution_date)
context.drop_spark_execution_partition(customers_dataset().identifier, context.execution_date)
context.drop_spark_execution_partition(transactions_dataset().identifier, context.execution_date)
context.drop_spark_execution_partition(customer_insights_dataset().identifier, context.execution_date)
context.drop_spark_execution_partition(ef().identifier, context.execution_date)
unblock_evaluation_for_execution_date(context, ef().identifier)
# Out:
# 2025-05-29 10:19:14,253:INFO:thetaray.common.logging:Partition does not exists, nothing to delete.
# 2025-05-29 10:19:14,583:INFO:thetaray.common.logging:Partition does not exists, nothing to delete.
# 2025-05-29 10:19:14,934:INFO:thetaray.common.logging:Partition does not exists, nothing to delete.
# 2025-05-29 10:19:14,935:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-05-29 10:19:15,237:INFO:thetaray.common.logging:Partition does not exists, nothing to delete.
# 2025-05-29 10:19:15,537:INFO:thetaray.common.logging:Partition does not exists, nothing to delete.
# True

# %% [markdown]
# ### Postgres

# %%
shared_namespace = os.environ["SHARED_NAMESPACE"]

engine_cdd = create_engine(
    f"postgresql+psycopg2://postgres:postgres@postgres.{shared_namespace}.svc.cluster.local:5432/cdd"
)

engine_apps = create_engine(
    f"postgresql+psycopg2://postgres:postgres@postgres.{shared_namespace}.svc.cluster.local:5432/apps_tmdemo"
)

# %%
# Set schema and eval flow to delete
schema_name = "solution_sonar"
eval_flow_id = ef().identifier

# Table Prefixes to Truncate for Each Eval Flow
eval_flow_table_prefixes = [
    "activity_",
    "activity_risk_",
    "test_activity_suppressed_",
    "test_activity_risk_",
    "test_activity_risk_thin_",
    "activity_risk_thin_",
    "test_activity_",
    "activity_suppressed_",
]

# Truncate
with engine_cdd.connect() as conn:
    for prefix in eval_flow_table_prefixes:
        table_full = prefix + eval_flow_id
        query = text(f"TRUNCATE TABLE {schema_name}.{table_full}")
        conn.execute(query)

with engine_cdd.connect() as conn:
    query = text(f"TRUNCATE TABLE {schema_name}.{transactions_dataset().identifier}")
    conn.execute(query)
    query = text(f"TRUNCATE TABLE {schema_name}.{customers_dataset().identifier}")
    conn.execute(query)
    query = text(f"TRUNCATE TABLE {schema_name}.{customer_insights_dataset().identifier}")
    conn.execute(query)
    query = text(f"TRUNCATE TABLE {schema_name}.tr_nodes_{graph().identifier}")
    conn.execute(query)
    query = text(f"TRUNCATE TABLE {schema_name}.tr_edges_{graph().identifier}")
    conn.execute(query)
# Out:
# 2025-05-29 10:19:17,373:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-05-29 10:19:17,386:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,387:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,387:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,388:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,388:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,388:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,388:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,389:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,389:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,390:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,390:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,390:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,409:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,410:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,410:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,410:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,411:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,411:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,411:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,412:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,412:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,412:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,412:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-05-29 10:19:17,413:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled

# %%
# Set schema and eval flow to delete
schema_name = "apps_tmdemo"
dpv = 'dpv:demo_ret_smb'

with engine_cdd.connect() as conn:
    query = text(f"SELECT alert_table_name FROM {schema_name}.rp_mappers WHERE data_permission = '{dpv}'")
    result = conn.execute(query).first()

with engine_cdd.connect() as conn:
    query = text(f"TRUNCATE TABLE {schema_name}.{result[0]}")
    conn.execute(query)

with engine_apps.connect() as conn:
    query = text(f"TRUNCATE TABLE investigation_center.{result[0]}")
    conn.execute(query)

mapper = result[0].split('_')[-1]

with engine_cdd.connect() as conn:
    query = text(f"DELETE FROM {schema_name}.rp_alerts WHERE alert_mapper_identifier = '{mapper}'")
    conn.execute(query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1230/1264848778.py in <module>
#       8
#       9 with engine_cdd.connect() as conn:
# ---> 10     query = text(f"TRUNCATE TABLE {schema_name}.{result[0]}")
#      11     conn.execute(query)
#      12
#
# TypeError: 'NoneType' object is not subscriptable

# %%
context.close()
