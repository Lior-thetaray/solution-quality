# %%
# from thetaray.api.tools.metadata import trigger_metadata_sync
# trigger_metadata_sync(allow_type_changes=True)

# %%
import datetime
from dateutil.relativedelta import relativedelta
import json
import logging
from pyspark.sql import DataFrame, Window, functions as f
from pyspark.sql import SQLContext
from pyspark.sql.types import LongType
import yaml

from common.libs import dates as dates_lib
from common.libs import features_discovery
from common.libs.features_executor import FeaturesExecutor
from common.libs.feature_engineering import max_look_back_monthly_features, max_look_back_daily_weekly_features
from common.libs.zscore import enrich_with_z_score
from common.factory.wrangling_execution_strategy import get_wrangling_execution_strategy
from common.factory.eval_flow_definition import get_evaluation_flow_definition
from common.factory.domain_definition import get_domain_definition
from common.notebook_utils.wrangling.wrangling_execution_strategy import WranglingExecutionStrategy
from common.definitions.domain import DomainDefinition
from common.definitions.eval_flow import EvaluationFlowDefinition
from common.libs.context_utils import get_dataset

from thetaray.api.context import init_context
from thetaray.api.dataset import dataset_functions
from thetaray.api.solution import IngestionMode
from thetaray.common import Constants
from thetaray.common.data_environment import DataEnvironment

logging.getLogger().handlers[0].setFormatter(logging.Formatter(fmt='%(levelname)s: %(asctime)s @ %(message)s',datefmt='%Y-%m-%d %H:%M:%S'))
logging.basicConfig(level=logging.INFO)

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


from thetaray.api.context import init_context
import datetime
from thetaray.common import Constants

from common.libs.config.loader import load_config
from common.libs.config.basic_execution_config_loader import BasicExecutionConfig, DevBasicExecutionConfig
from common.libs.context_utils import is_run_triggered_from_airflow



with open('/thetaray/git/solutions/domains/demo_fuib/config/spark_config.yaml') as spark_config_file:
    spark_config = yaml.load(spark_config_file, yaml.FullLoader)['spark_config_a']

execution_date=datetime.datetime(1970, 1, 1)

context = init_context(domain='demo_fuib',
                       execution_date=execution_date,
                       spark_conf=spark_config,
                       spark_master='local[*]',
                       allow_type_changes=True)

spark = context.get_spark_session()
sc = SQLContext(spark)
params = context.parameters
print(f"Spark UI URL: {context.get_spark_ui_url()}")

print(json.dumps(params, indent=4))
# Out:
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# 2025-09-15 10:11:44,946:INFO:thetaray.common.logging:start loading solution.....[ load_risks=True , solution_path=/thetaray/git/solutions/domains , settings_path=/thetaray/git/solutions/settings ]
# 2025-09-15 10:11:44,955:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:44,969:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_indiv_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,115:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_digital_wallets_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,130:WARNING:thetaray.common.logging:Encryption is enabled on dataset customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,130:WARNING:thetaray.common.logging:Encryption is enabled on dataset transaction, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,132:WARNING:thetaray.common.logging:Encryption is enabled on dataset party_wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,159:WARNING:thetaray.common.logging:Encryption is enabled on dataset wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,161:WARNING:thetaray.common.logging:Encryption is enabled on dataset account, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,163:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_pay_proc_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,174:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_remittance_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,184:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_nested_banking_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,256:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_merchant_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,271:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_human_trafficking_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,470:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,471:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property CN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,472:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,473:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,474:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property CN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,475:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,476:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:11:45,496:WARNING:thetaray.common.logging:Parameter must be unique within the evaluation flow [demo_ret_smb_ef][{'tr_rb_param_1': ['high_cash_withdrawal', 'high_transfer_jurisd']}]
# 2025-09-15 10:11:45,609:INFO:thetaray.common.logging:load_risks took: 0.12981224060058594
# 2025-09-15 10:11:45,832:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,832:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_indiv_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_digital_wallets_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset transaction, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset party_wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset account, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_pay_proc_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_remittance_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,833:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_nested_banking_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,834:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_merchant_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:11:45,834:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_human_trafficking_insights, but data encryption is disabled in deployment
# INFO: 2025-09-15 10:11:46 @ === Started updating schema ===
# INFO: 2025-09-15 10:11:46 @ === Started updating schema on Postgres ===
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:11:56 @ === Finished updating schema ===
# INFO: 2025-09-15 10:11:58 @ === Started updating schema for Datasets on Minio ===
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/15 10:12:00 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/09/15 10:12:00 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Hive Session ID = 5c853abc-11f6-415c-8cab-774e22b9e6ce
# 25/09/15 10:12:02 INFO SessionState: Hive Session ID = 5c853abc-11f6-415c-8cab-774e22b9e6ce
# 25/09/15 10:12:13 INFO SQLStdHiveAccessController: Created SQLStdHiveAccessController for session context : HiveAuthzSessionContext [sessionString=5c853abc-11f6-415c-8cab-774e22b9e6ce, clientType=HIVECLI]
# INFO: 2025-09-15 10:12:16 @ === Finished updating schema for Datasets on Minio ===
# INFO: 2025-09-15 10:12:16 @ === Started updating schema for Evaluation Flows on Minio ===
# Added `alias` successfully.
# INFO: 2025-09-15 10:12:21 @ === Finished updating schema for Evaluation Flows on Minio ===
# Added `alias` successfully.
# Spark UI URL: https://jupyterhub-platform-thetalab.sonar.thetaray.cloud/user/andre.gutnik/proxy/4041/jobs/
# {}
# /opt/spark/python/pyspark/sql/context.py:113: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
from thetaray.api.decisioning.api import identify_risks
from thetaray.common.data_environment import DataEnvironment

# %%
identify_risks(context, 'cust_month_ef', data_environment=DataEnvironment.PUBLIC, ignore_block=True)
# Out:
# INFO: 2025-09-15 10:12:24 @ clear previous run(for re-run only), took 0.06985092163085938 seconds.
# INFO: 2025-09-15 10:12:24 @ compute enrichment/variables(activity_...), took 0.2099285125732422 seconds.
# INFO: 2025-09-15 10:12:24 @ compute risks(activity_risk_thin...), took 0.09728026390075684 seconds.
# INFO: 2025-09-15 10:12:24 @ process and save 446 risks,[chunk_size=10,fetch_size=10000]
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# INFO: 2025-09-15 10:12:28 @ save risk(activity_risk...), took 3.830289840698242 seconds.
# INFO: 2025-09-15 10:12:28 @ add combined metadata for risk cust_monthly_anomaly, evaluation cust_month_ef
# INFO: 2025-09-15 10:12:28 @ compute suppression(activity_suppressed...), took 0.11019587516784668 seconds.
# INFO: 2025-09-15 10:12:28 @ 446 risks of evaluation flow cust_month_ef saved successfully date range [context 1970-01-01 00:00:00, from_job_ts None, to_job_ts None]
# True

# %%
context.close()
