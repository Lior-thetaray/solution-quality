# %%
import datetime
from dateutil.relativedelta import relativedelta
import json
import logging
from pyspark.sql import DataFrame, Window, functions as f
from pyspark.sql import SQLContext
from pyspark.sql.types import LongType
import yaml

from common.libs import dates as dates_lib
from common.libs import features_discovery
from common.libs.features_executor import FeaturesExecutor
from common.libs.feature_engineering import max_look_back_monthly_features, max_look_back_daily_weekly_features
from common.libs.zscore import enrich_with_z_score
from common.factory.wrangling_execution_strategy import get_wrangling_execution_strategy
from common.factory.eval_flow_definition import get_evaluation_flow_definition
from common.factory.domain_definition import get_domain_definition
from common.notebook_utils.wrangling.wrangling_execution_strategy import WranglingExecutionStrategy
from common.definitions.domain import DomainDefinition
from common.definitions.eval_flow import EvaluationFlowDefinition
from common.libs.context_utils import get_dataset

from thetaray.api.context import init_context
from thetaray.api.dataset import dataset_functions
from thetaray.api.solution import IngestionMode
from thetaray.common import Constants
from thetaray.common.data_environment import DataEnvironment

logging.getLogger().handlers[0].setFormatter(logging.Formatter(fmt='%(levelname)s: %(asctime)s @ %(message)s',datefmt='%Y-%m-%d %H:%M:%S'))
logging.basicConfig(level=logging.INFO)

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


from thetaray.api.context import init_context
import datetime
from thetaray.common import Constants

from common.libs.config.loader import load_config
from common.libs.config.basic_execution_config_loader import BasicExecutionConfig, DevBasicExecutionConfig
from common.libs.context_utils import is_run_triggered_from_airflow



with open('/thetaray/git/solutions/domains/demo_fuib/config/spark_config.yaml') as spark_config_file:
    spark_config = yaml.load(spark_config_file, yaml.FullLoader)['spark_config_a']

execution_date=datetime.datetime(1970, 1, 1)

context = init_context(domain='demo_fuib',
                       execution_date=execution_date,
                       spark_conf=spark_config,
                       spark_master='local[*]',
                       allow_type_changes=True)

spark = context.get_spark_session()
sc = SQLContext(spark)
params = context.parameters
print(f"Spark UI URL: {context.get_spark_ui_url()}")

print(json.dumps(params, indent=4))
# Out:
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# 2025-09-15 10:13:37,222:INFO:thetaray.common.logging:start loading solution.....[ load_risks=True , solution_path=/thetaray/git/solutions/domains , settings_path=/thetaray/git/solutions/settings ]
# 2025-09-15 10:13:37,232:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,246:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_indiv_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,391:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_digital_wallets_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,405:WARNING:thetaray.common.logging:Encryption is enabled on dataset customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,405:WARNING:thetaray.common.logging:Encryption is enabled on dataset transaction, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,407:WARNING:thetaray.common.logging:Encryption is enabled on dataset party_wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,434:WARNING:thetaray.common.logging:Encryption is enabled on dataset wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,436:WARNING:thetaray.common.logging:Encryption is enabled on dataset account, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,438:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_pay_proc_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,449:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_remittance_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,459:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_nested_banking_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,528:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_merchant_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,542:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_human_trafficking_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:37,736:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,736:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,736:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,737:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property CN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,738:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,739:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,740:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,741:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property CN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property AN is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,742:WARNING:thetaray.common.logging:Node AC is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Property PI is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Property NM is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Property AD is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Property CT is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Node PR is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Edge TX is missing is_monetary property. Defaulting to True
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,743:WARNING:thetaray.common.logging:Edge ER is configured as encrypted, but data encryption is disabled
# 2025-09-15 10:13:37,763:WARNING:thetaray.common.logging:Parameter must be unique within the evaluation flow [demo_ret_smb_ef][{'tr_rb_param_1': ['high_cash_withdrawal', 'high_transfer_jurisd']}]
# 2025-09-15 10:13:37,876:INFO:thetaray.common.logging:load_risks took: 0.12998747825622559
# 2025-09-15 10:13:38,096:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_smb_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,096:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_ret_indiv_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,097:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_digital_wallets_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,097:WARNING:thetaray.common.logging:Encryption is enabled on dataset customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,097:WARNING:thetaray.common.logging:Encryption is enabled on dataset transaction, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,097:WARNING:thetaray.common.logging:Encryption is enabled on dataset party_wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,097:WARNING:thetaray.common.logging:Encryption is enabled on dataset wrangling, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,097:WARNING:thetaray.common.logging:Encryption is enabled on dataset account, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,097:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_pay_proc_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,098:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_remittance_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,098:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_nested_banking_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,098:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_merchant_customer_insights, but data encryption is disabled in deployment
# 2025-09-15 10:13:38,098:WARNING:thetaray.common.logging:Encryption is enabled on dataset demo_human_trafficking_insights, but data encryption is disabled in deployment
# INFO: 2025-09-15 10:13:38 @ === Started updating schema ===
# INFO: 2025-09-15 10:13:38 @ === Started updating schema on Postgres ===
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ found 213 tables in solution public schema
# INFO: 2025-09-15 10:13:48 @ === Finished updating schema ===
# INFO: 2025-09-15 10:13:50 @ === Started updating schema for Datasets on Minio ===
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/15 10:13:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/09/15 10:13:52 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Hive Session ID = 40afc684-a149-4d20-b141-af5b32901623
# 25/09/15 10:13:54 INFO SessionState: Hive Session ID = 40afc684-a149-4d20-b141-af5b32901623
# 25/09/15 10:14:05 INFO SQLStdHiveAccessController: Created SQLStdHiveAccessController for session context : HiveAuthzSessionContext [sessionString=40afc684-a149-4d20-b141-af5b32901623, clientType=HIVECLI]
# INFO: 2025-09-15 10:14:08 @ === Finished updating schema for Datasets on Minio ===
# INFO: 2025-09-15 10:14:08 @ === Started updating schema for Evaluation Flows on Minio ===
# Added `alias` successfully.
# INFO: 2025-09-15 10:14:13 @ === Finished updating schema for Evaluation Flows on Minio ===
# Added `alias` successfully.
# Spark UI URL: https://jupyterhub-platform-thetalab.sonar.thetaray.cloud/user/andre.gutnik/proxy/4041/jobs/
# {}
# /opt/spark/python/pyspark/sql/context.py:113: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
from thetaray.api.distribution import distribute_alerted_activities
from thetaray.common.data_environment import DataEnvironment
distribute_alerted_activities(context, evaluation_flow_identifier = 'cust_month_ef', distribution_target_identifier = 'apps_tmdemo',data_environment=DataEnvironment.PUBLIC) #TODO: complete
# Out:
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# INFO: 2025-09-15 10:14:21 @ Received request with Id: bf8830dc-921c-11f0-9a70-3e1113e9ae03 and required work slots amount 4 at 2025-09-15 10:14:21.859887
# INFO: 2025-09-15 10:14:21 @ Work slots acquired for request with request_id: bf8830dc-921c-11f0-9a70-3e1113e9ae03
# INFO: 2025-09-15 10:14:28 @ Locking execution dates: [datetime.datetime(1970, 1, 1, 0, 0)] for evaluation flow: cust_month_ef
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/starlette/config.py:60: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /thetaray/venv/lib64/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'keycloak-shared-thetalab.sonar.thetaray.cloud'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
context.close()
