# %%
from thetaray.api.context import init_context
import datetime
context = init_context(execution_date=datetime.datetime(1970,1,1))
from thetaray.api.evaluation import publish_evaluated_activities
publish_evaluated_activities(context, 'tr_analysis')
