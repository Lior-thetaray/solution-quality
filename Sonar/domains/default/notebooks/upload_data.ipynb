# %%
from thetaray.api.context import init_context
import datetime

spark_conf={
    "spark.executor.memory": "1g",
    "spark.executor.cores": "1",
    "spark.executor.instances": "4" 
}

context = init_context(execution_date=datetime.datetime(1970,1,1), spark_conf=spark_conf)

# %%
from thetaray.api.connector.upload import upload

upload(context, "account")
upload(context, "card")
upload(context, "client")
upload(context, "disp")
upload(context, "district")
upload(context, "loan")
upload(context, "transaction")
upload(context, "order")
upload(context, "country_risk")

# %%
context.close()
